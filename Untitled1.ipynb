# %%
spark=SparkSession\
.builder\
.config("spark.jars.packages","org.apache.hadoop:hadoop-aws:2.7.3,com.amazonaws:aws-java-sdk:1.7.4")\
.config("fs.s3a.impl","org.apache.hadoop.fs.s3a.S3AFileSystem")\
.config("fs.s3a.access.key","AKIA2EL6SZIG2BKWBWUC")\
.config("fs.s3a.secret.key","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")\
.getOrCreate()

# %%
df=spark.read.option("header","true").option("interschema","true").orc("s3a://presto-prod-otipy/otipy-database/backup/consumer/agent_polygon_history/dt=2022-07-07/22219c66-bf6b-47e3-97e4-8651d9d32b17.orc")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df=spark.read.option("header","true").option("interschema","true").orc("s3a://presto-prod-otipy/otipy-database/backup/consumer/agent_polygon_history/dt=2022-07-07/22219c66-bf6b-47e3-97e4-8651d9d32b17.orc")
#
# File C:\bigdatasetup\spark\python\pyspark\sql\readwriter.py:463, in DataFrameReader.orc(self, path, mergeSchema, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter)
#     461 if isinstance(path, str):
#     462     path = [path]
# --> 463 return self._df(self._jreader.orc(_to_seq(self._spark._sc, path)))
#
# File C:\bigdatasetup\spark\python\lib\py4j-0.10.9.3-src.zip\py4j\java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
# ...

# %%
df=spark.read.orc("s3a://presto-prod-otipy/otipy-database/backup/consumer/agent_polygon_history/dt=2022-07-07/22219c66-bf6b-47e3-97e4-8651d9d32b17.orc")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df=spark.read.orc("s3a://presto-prod-otipy/otipy-database/backup/consumer/agent_polygon_history/dt=2022-07-07/22219c66-bf6b-47e3-97e4-8651d9d32b17.orc")
#
# File C:\bigdatasetup\spark\python\pyspark\sql\readwriter.py:463, in DataFrameReader.orc(self, path, mergeSchema, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter)
#     461 if isinstance(path, str):
#     462     path = [path]
# --> 463 return self._df(self._jreader.orc(_to_seq(self._spark._sc, path)))
#
# File C:\bigdatasetup\spark\python\lib\py4j-0.10.9.3-src.zip\py4j\java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
# ...
