# %%
import s3fs
import boto3

fs = s3fs.S3FileSystem(key='AKIA2EL6SZIG2BKWBWUC',secret='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')

file_name=[]
table=[]
consumer_table=[]
crofarmUsers_tables=[]
products_tables=[]
temp_finance_tables=[]
a=fs.ls('presto-prod-otipy/otipy-database/backup-full-load/consumer')
b=fs.ls('presto-prod-otipy/otipy-database/backup-full-load/crofarmUsers')
c=fs.ls('presto-prod-otipy/otipy-database/backup-full-load/products')
d=fs.ls('presto-prod-otipy/otipy-database/backup-full-load/temp_finance')

for i in range(len(a)):
    if(a[i].split("/")[3]=='consumer'):
        table.append(a[i].split("/")[4])
        consumer_table.append(a[i].split("/")[4])
for i in range(len(consumer_table)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/backup-full-load/consumer/'+consumer_table[i]))

for i in range(len(b)):   
    if(b[i].split("/")[3]=='crofarmUsers'):
        table.append(b[i].split("/")[4])
        crofarmUsers_tables.append(b[i].split("/")[4])
for i in range(len(crofarmUsers_tables)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/backup-full-load/crofarmUsers/'+crofarmUsers_tables[i]))

for i in range(len(c)):  
    if(c[i].split("/")[3]=='products'):
        table.append(c[i].split("/")[4])
        products_tables.append(c[i].split("/")[4])
for i in range(len(products_tables)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/backup-full-load/products/'+products_tables[i]))
    

# for i in range(len(d)):  
#     if(d[i].split("/")[3]=='temp_finance'):
#         table.append(d[i].split("/")[4])
#         temp_finance_tables.append(d[i].split("/")[4])
# for i in range(len(temp_finance_tables)):
#     file_name.append(fs.ls('presto-prod-otipy/otipy-database/backup-full-load/temp_finance/'+temp_finance_tables[i])[0])

# final_file_name=[]    
# for i in range(len(file_name)):
#     final_file_name.append(("/".join((fs.ls(file_name[i]))[0].split("/")[1:])))



# s3_client = boto3.client(
#     "s3",
#     aws_access_key_id='AKIA2EL6SZIG2BKWBWUC',
#     aws_secret_access_key='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',
# )
# s3 = boto3.resource('s3')
# BUCKET_NAME = 'presto-prod-otipy'
# create_table=[]
# for j in range(len(final_file_name)):
#     if(final_file_name[j].split("/")[2]=='consumer'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc" )
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.historical.full_consumer_"+table[j]+ ('[%s]' % ', '.join(map(str, n))).replace("]",",")+" dt varchar)")
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/backup-full-load/consumer/"+table[j]+"', format='ORC')")
#         create_table.append(x)
#     if(final_file_name[j].split("/")[2]=='crofarmUsers'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.historical.full_crofarmusers_"+table[j]+ ('[%s]' % ', '.join(map(str, n))).replace("]",",")+" dt varchar)")
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/backup-full-load/crofarmUsers/"+table[j]+"', format='ORC')")
#         create_table.append(x)
#     if(final_file_name[j].split("/")[2]=='products'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.historical.full_products_"+table[j]+ ('[%s]' % ', '.join(map(str, n))).replace("]",",")+" dt varchar)")
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/backup-full-load/products/"+table[j]+"', format='ORC')")
#         create_table.append(x)

# %%
final_file_name
# Out:
# []

# %%
print(file_name)
# Out:
# [['presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-13', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-14', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-15', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-16', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-17', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-18', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-19', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-20', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-21', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-22', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-23', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-24', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-25', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-26', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-27', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-28', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-29', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-30', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-07-31', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-01', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-02', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-03', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-04', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-05', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-06', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-07', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-08', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-09', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-10', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-11', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-12', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-13', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-14', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-15', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-16', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-17', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-18', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-19', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-20', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_coupon/dt=2022-08-21', 'presto-prod-otipy/otipy-database/backup-full-load/consumer/agent_consumer_cou ...

# %%
del_file=[]
for i in range(len(file_name)):
    del_file.append(str(file_name[i][-1]))

# %%
final_del_file=[]
for i in range(len(del_file)):
   final_del_file.append("/".join(del_file[i].split('/')[1:]))

# %%
len(final_del_file)
# Out:
# 172

# %%
import boto3
s3 = boto3.resource('s3')
bucket = s3.Bucket('presto-prod-otipy')
for i in range(len(final_del_file)):
    for obj in bucket.objects.filter(Prefix=final_del_file[i]):
        s3.Object(bucket.name,obj.key).delete()

# %%
len(file_name)
# Out:
# 44

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('presto-prod-otipy')
bucket.objects.filter(Prefix="myprefix/").delete()

# %%
from boto.s3.connection import S3Connection, Bucket, Key

conn = S3Connection('AKIA2EL6SZIG2BKWBWUC', 'r9vA5tjPqtuZICraRfOpoN8p8XLxuV62oisJQMxl')

b = Bucket(conn,'presto-prod-otipy')

k = Key(b)

k.key = 'dt=2022-09-02'

b.delete_key(k)
# Out:
# ---------------------------------------------------------------------------
# S3ResponseError                           Traceback (most recent call last)
# Input In [24], in <cell line: 11>()
#       7 k = Key(b)
#       9 k.key = 'dt=2022-09-02'
# ---> 11 b.delete_key(k)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto\s3\bucket.py:759, in Bucket.delete_key(self, key_name, headers, version_id, mfa_token)
#     757 if not key_name:
#     758     raise ValueError('Empty key names are not allowed')
# --> 759 return self._delete_key_internal(key_name, headers=headers,
#     760                                  version_id=version_id,
#     761                                  mfa_token=mfa_token,
#     762                                  query_args_l=None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto\s3\bucket.py:780, in Bucket._delete_key_internal(self, key_name, headers, version_id, mfa_token, query_args_l)
#     778 body = response.read()
#     779 if response.status != 204:
# --> 780     raise provider.storage_response_error(response.status,
#     781                                           response.reason, body)
#     782 else:
#     783     # return a key object with information on what was deleted.
#     784     k = self.key_class(self)
#
# S3ResponseError: S3ResponseError: 400 Bad Request
# <?xml version="1.0" encoding="UTF-8"?>
# <Error><Code>InvalidRequest</Code><Message>The authorization mechanism you have provided is not supported. Please use AWS4-HMAC-SHA256.</Message><RequestId>XJS6TAEZXXD4Z6FW</RequestId><HostId>UD/DbHpKyoVgAKzublrF03I9TSGsGUXkmAMgpDorzl368+NSO1sWHYCXEZnSVJu8avPBssIo6p8=</HostId></Error>

# %%
import boto3   
s3 = boto3.client('s3')
s3.delete_object(Bucket="presto-prod-otipy", Key="otipy-database/backup-full-load/consumer/sms_mapping/dt=2022-09-02")
# Out:
# {'ResponseMetadata': {'RequestId': 'NDE9SR14E5062GGY',
#   'HostId': 'z26kO2+FYNdw00q9+mG/fKPHHSo621xo31EVPTFcb1NqhiUCsQ7qS4GqEagIPEpB18g8lzHYeRQ=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'z26kO2+FYNdw00q9+mG/fKPHHSo621xo31EVPTFcb1NqhiUCsQ7qS4GqEagIPEpB18g8lzHYeRQ=',
#    'x-amz-request-id': 'NDE9SR14E5062GGY',
#    'date': 'Fri, 02 Sep 2022 12:47:08 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
print(fs.rm_file('presto-prod-otipy/otipy-database/backup-full-load/consumer/sms_mapping/dt=2022-09-02/*'))
# Out:
# None

# %%
import sh
s3 = sh.bash.bake("aws s3")
# s3.put("file","s3n://bucket/file")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 import sh
#       2 s3 = sh.bash.bake("aws s3")
#
# ModuleNotFoundError: No module named 'sh'

# %%
pip install sh
# Out:
# Collecting sh
#   Using cached sh-1.14.3.tar.gz (62 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\Agrim\AppData\Local\Temp\pip-install-j20kowuf\sh_0ae3a845ef8746928767db98e27a420d\setup.py", line 5, in <module>
#       import sh
#     File "C:\Users\Agrim\AppData\Local\Temp\pip-install-j20kowuf\sh_0ae3a845ef8746928767db98e27a420d\sh.py", line 37, in <module>
#       import fcntl
#   ModuleNotFoundError: No module named 'fcntl'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)

# %%
import boto3
# s3 = boto3.resource("s3")
s3 = boto3.client(
            "s3", aws_access_key_id='AKIA2EL6SZIG2BKWBWUC', aws_secret_access_key='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'
        )
s3.delete_object(Bucket="presto-prod-otipy", Key="otipy-database/backup-full-load/consumer/sms_mapping/dt=2022-09-02/*")
# Out:
# {'ResponseMetadata': {'RequestId': '0CCQW87EXB138G5N',
#   'HostId': 'Frx71NLahNlzpB5nQQ2r94M4GUp/sep3RE4zIEmE4+dt7JBd7itNy9ygc7xkVYbUBe6UrlfsSUI=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'Frx71NLahNlzpB5nQQ2r94M4GUp/sep3RE4zIEmE4+dt7JBd7itNy9ygc7xkVYbUBe6UrlfsSUI=',
#    'x-amz-request-id': '0CCQW87EXB138G5N',
#    'date': 'Fri, 02 Sep 2022 13:07:11 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0}}

# %%
def delete_from_s3(bucket, model, aws_secret, aws_key):
    try:
        s3 = boto3.client(
            "s3", aws_access_key_id='AKIA2EL6SZIG2BKWBWUC', aws_secret_access_key='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'
        )
        s3.delete_object(Bucket=bucket, Key=model)
        return True
    except Exception as ex:
        print(str(ex))
        return False
