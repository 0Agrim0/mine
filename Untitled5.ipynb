# %%
import pandas as pd
idx = pd.date_range("00:00:00", "23:59:59", freq="S",)

# %%
import numpy as np
a=np.array(idx)

# %%
df=pd.DataFrame(a)

# %%
df.
# Out:
# 0       2022-06-24 00:00:00
# 1       2022-06-24 00:00:01
# 2       2022-06-24 00:00:02
# 3       2022-06-24 00:00:03
# 4       2022-06-24 00:00:04
#                 ...
# 86395   2022-06-24 23:59:55
# 86396   2022-06-24 23:59:56
# 86397   2022-06-24 23:59:57
# 86398   2022-06-24 23:59:58
# 86399   2022-06-24 23:59:59
# Name: 0, Length: 86400, dtype: datetime64[ns]

# %%
pip install trino.dbapi
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement trino.dbapi (from versions: none)
# ERROR: No matching distribution found for trino.dbapi
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\agrim\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
from trino.dbapi import connect

conn = connect(
    host="173.0.134.177",
    port=8080,
    user="trino",
    catalog="hive"
)
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM consumer.cn_order where dt='2022-06-21' limit 100")
rows = cur.fetchall()

# %%
rows
# Out:
# [[5359974,
#   152803,
#   53482,
#   8,
#   152843,
#   'D',
#   '2129.00',
#   '0.00',
#   'Some thing problem.',
#   '06:00 AM - 10:00 AM, 22 JUN, WED',
#   220622,
#   '2129.00',
#   '',
#   1655861640,
#   0,
#   1,
#   '1528031655770908461',
#   1,
#   '~CT35493~CT61149~CT21533',
#   4,
#   '2022-06-21T00:04:49.633017',
#   11,
#   0,
#   '',
#   '2.00',
#   1655877946,
#   1655853372,
#   'Table_6 Noida',
#   True,
#   1,
#   1425,
#   True,
#   0,
#   1655830041,
#   '2119.00',
#   'BN10352',
#   0,
#   0,
#   41607,
#   6,
#   0,
#   0,
#   '',
#   '',
#   '',
#   0,
#   0,
#   True,
#   True,
#   '',
#   None,
#   False,
#   '2022-06-21'],
#  [5359975,
#   1800926,
#   50000,
#   6,
#   1803270,
#   'D',
#   '102.00',
#   '0.00',
#   '',
#   '06:00 AM - 10:00 AM, 22 JUN, WED',
#   220622,
#   '102.00',
#   '',
#   1655863513,
#   0,
#   1,
#   '18009261655769440868',
#   1,
#   '~CT51435',
#   1,
#   '2022-06-21T00:04:57.330809',
#   7,
#   0,
#   '',
#   '5.00',
# ...
