# %%
import s3fs
import boto3

fs = s3fs.S3FileSystem(key='AKIA2EL6SZIG2BKWBWUC',secret='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')

file_name=[]
table=[]
consumer_table=[]
crofarmUsers_tables=[]
products_tables=[]

a=fs.ls('presto-prod-otipy/otipy-database/live/consumer')
b=fs.ls('presto-prod-otipy/otipy-database/live/crofarmUsers')
c=fs.ls('presto-prod-otipy/otipy-database/live/products')

for i in range(len(a)):
    if(a[i].split("/")[3]=='consumer'):
        table.append(a[i].split("/")[4])
        consumer_table.append(a[i].split("/")[4])
for i in range(len(consumer_table)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/live/consumer/'+consumer_table[i])[0])

for i in range(len(b)):   
    if(b[i].split("/")[3]=='crofarmUsers'):
        table.append(b[i].split("/")[4])
        crofarmUsers_tables.append(b[i].split("/")[4])
for i in range(len(crofarmUsers_tables)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/live/crofarmUsers/'+crofarmUsers_tables[i])[0])

for i in range(len(c)):  
    if(c[i].split("/")[3]=='products'):
        table.append(c[i].split("/")[4])
        products_tables.append(c[i].split("/")[4])
for i in range(len(products_tables)):
    file_name.append(fs.ls('presto-prod-otipy/otipy-database/live/products/'+products_tables[i])[0])
    



final_file_name=[]    
for i in range(len(file_name)):
    final_file_name.append(("/".join((fs.ls(file_name[i]))[0].split("/")[1:])))

# s3_client = boto3.client(
#     "s3",
#     aws_access_key_id='AKIA2EL6SZIG2BKWBWUC',
#     aws_secret_access_key='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',
# )
# s3 = boto3.resource('s3')
# BUCKET_NAME = 'presto-prod-otipy'
# create_table=[]
# for j in range(len(final_file_name)):
#     if(final_file_name[j].split("/")[2]=='consumer'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc" )
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.consumer."+table[j]+ '[%s]' % ', '.join(map(str, n)))
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/live/consumer/"+table[j]+"', format='ORC')")
#         create_table.append(x)
#     if(final_file_name[j].split("/")[2]=='crofarmUsers'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.crofarmusers."+table[j]+ '[%s]' % ', '.join(map(str, n)))
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/live/crofarmUsers/"+table[j]+"', format='ORC')")
#         create_table.append(x)
#     if(final_file_name[j].split("/")[2]=='products'):
#         KEY=final_file_name[j]
#         s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
#         df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#         n=[]
#         for field in df.schema.fields:
#             if(str(field.dataType).replace("Type","")=="String"):
#                 n.append(field.name +" "+str("varchar"))
#             elif(str(field.dataType).replace("Type","")=="Long"):
#                 n.append(field.name +" "+str("bigint"))
#             else:
#                 n.append(field.name +" "+str(field.dataType).replace("Type",""))
#         o=("CREATE TABLE IF NOT EXISTS hive.products."+table[j]+ '[%s]' % ', '.join(map(str, n)))
#         x = o.replace("[", "(")
#         x=x.replace("]",")")
#         x=(x+" WITH( partitioned_by = array['dt'],external_location = 's3a://presto-prod-otipy/otipy-database/live/products/"+table[j]+"', format='ORC')")
#         create_table.append(x)

# %%
for j in range(len(final_file_name)):
    if('dt' not in (final_file_name[j].split("/")[4])):
        if(final_file_name[j].split("/")[2]=='products'):
            KEY=final_file_name[j]
            s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
            df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
            n=[]
            for field in df.schema.fields:
                if(str(field.dataType).replace("Type","")=="String"):
                    n.append(field.name +" "+str("varchar"))
                elif(str(field.dataType).replace("Type","")=="Long"):
                    n.append(field.name +" "+str("bigint"))
                else:
                    n.append(field.name +" "+str(field.dataType).replace("Type",""))
            o=("CREATE TABLE IF NOT EXISTS hive.products."+table[j]+ '[%s]' % ', '.join(map(str, n)))
            x = o.replace("[", "(")
            x=x.replace("]",")")
            x=(x+" WITH(external_location = 's3a://presto-prod-otipy/otipy-database/live/products/"+table[j]+"', format='ORC')")
            create_table.append(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       3 if(final_file_name[j].split("/")[2]=='products'):
#       4     KEY=final_file_name[j]
# ----> 5     s3.Bucket(BUCKET_NAME).download_file(KEY,'abs'+str(j)+".orc")
#       6     df = sqlContext.read.format('orc').load("abs"+str(j)+".orc")
#       7     n=[]
#
# NameError: name 's3' is not defined

# %%
final_file_name
# Out:
# ['otipy-database/live/consumer/Update_partner_ticket/000ce291-c81c-49bc-bf92-03e0f4189115.orc',
#  'otipy-database/live/consumer/agent_polygon_history/00786833-bbfe-47b8-8736-c0817435d8eb.orc',
#  'otipy-database/live/consumer/agent_reactivate_consumer_mapping/00032ca6-64c8-4909-89e4-850e5b0fe4d1.orc',
#  'otipy-database/live/consumer/agent_reactivation_share/0014dd89-e2ea-4366-a1c8-bc1dd454d009.orc',
#  'otipy-database/live/consumer/agent_referral/00c22b13-a0d5-4577-ab86-4d4de9d8be6a.orc',
#  'otipy-database/live/consumer/agent_refund/0a387645-bf34-4ae9-922a-f0d50471998d.orc',
#  'otipy-database/live/consumer/agent_wise_target/1e570fff-14d6-47dc-b8bb-334600c066b7.orc',
#  'otipy-database/live/consumer/cn_agent_item_incentive/00067e46-56c3-4317-bc9e-5b83042c7892.orc',
#  'otipy-database/live/consumer/consumer_identifier/000010bd-2e56-4213-9e8a-2356c743379f.orc',
#  'otipy-database/live/consumer/consumer_item_refund/00008ae4-e718-4501-b663-47023fc1dee9.orc',
#  'otipy-database/live/consumer/consumer_leads/b2423a14-e805-4415-af30-95caaf828c7f.orc',
#  'otipy-database/live/consumer/consumer_promo_balance/0006e3d7-5212-4185-89e1-1ced70dfe21b.orc',
#  'otipy-database/live/consumer/consumer_referrals/0002f354-4ede-4ade-93fa-5fbc418cff5c.orc',
#  'otipy-database/live/consumer/consumer_retention_lead/00663840-2af7-4674-bb82-cb14ce61cce0.orc',
#  'otipy-database/live/consumer/customer_move_history/03ca55a2-925c-4293-bb21-64e1b01aaa82.orc',
#  'otipy-database/live/consumer/delete_ticket/0009f9c6-1c53-451d-af98-eb1e50c2aeb8.orc',
#  'otipy-database/live/consumer/delivery_rating/0002a1cd-dac3-48f7-9046-a2f6069ff0fa.orc',
#  'otipy-database/live/consumer/erp_marketing_campaign/003c9df3-efda-4005-8992-d759254d3d51.orc',
#  'otipy-database/live/consumer/fresh_desk_ticket/832d7c4e-d25a-4689-bc60-d05461ade621.orc',
#  'otipy-database/live/consumer/gokwik_transaction/dt=2021-06-30/20220713_175357_09074_n8n8g_def5acc1-3012-4196-b060-4f591b590606',
#  'otipy-database/live/consumer/icici_transaction/dt=2021-09-09/20220713_175449_09113_n8n8g_775254f8-eafb-434b-bdc9-7ed3afffc9bd',
#  'otipy-database/live/consumer/lead_delete_request/0145ef8d-ed00-4a2e-b98b-07366dcba54b.orc',
#  'otipy-database/live/consumer/ops_picking_property/008a1abd-2deb-4736-b91a-89ad8701841b.orc',
#  'otipy-database/live/consumer/otipy_metrics/02c9c1a0-b5f0-447a-8e3a-3cfc69ba251b.orc',
#  'otipy-database/live/consumer/partner_change_history/0007ea34-98f4-43b8-8bda-f60ba2f352c5.orc',
#  'otipy-database/live/consumer/partner_consumer_invite/00502cfe-1ef0-4126-b981-ab0a890f5e3a.orc',
#  'otipy-database/live/consumer/partner_consumer_referral_mapping/005108c2-f360-46be-b078-850af22b2a9f.orc',
#  'otipy-database/live/consumer/payment_monitor/003fe0b7-3f74-45bf-9681-566a6f46ad5e.orc',
#  'otipy-database/live/consumer/sodexo_transaction/dt=2021-12-09/20220713_175531_09152_n8n8g_a7f4f324-380a-42a8-9592-b103800a8fff',
#  'otipy-database/live/consumer/stock_out_notify/0003a275-924f-45ac-bbb8-a05cd1d6842f.orc',
#  'otipy-database/live/consumer/support_partner_change_history/00124e6d-8187-43de-81a8-b610ed8177c5.orc',
#  'otipy-database/live/consumer/upi_transaction/dt=2021-06-30/20220713_175607_09182_n8n8g_01c2d4fc-c490-4465-bd1b-487b945c7253',
#  'otipy-database/live/consumer/user_scanner_track/002bdd7b-f0b0-4f0f-a203-2b39a6288963.orc',
#  'otipy-database/live/consumer/wallet_balance_history/00441044-7507-4cf3-9924-44714504b242.orc',
#  'otipy-database/live/consumer/whatsapp_messages/00054db5-d84c-41ae-9f52-abb85f3d94a4.orc',
#  'otipy-database/live/crofarmUsers/cr_distributor_retailer_mapping/050ab97a-597c-4859-992e-3960915c570a.orc',
#  'otipy-database/live/products/inventory_transaction/000245a4-fd51-464e-b67c-fe233637c2c3.orc',
#  'otipy-database/live/products/locus_batch_task/0274e8a9-14c4-4e53-ad14-982587c547cb.orc',
#  'otipy-database/live/products/locus_driver_mapping/00296a8a-1480-4315-8915-ee68f90caa74.orc',
#  'otipy-database/live/products/noti_user_mapping/2a26c295-664c-4648-9a3f-e075c64608e3.orc',
#  'otipy-database/live/products/order_marketing_cost/0002565c-f75e-41ce-89b0-a0b2916b1afb.orc',
#  'otipy-database/live/products/otipy_calling/0010512b-c1f9-455b-9058-d23f58a777a8.orc',
#  'otipy-database/live/products/partner_freshworks_data/00e59962-84b7-4a17-b824-163f184d0e1e.orc',
#  'otipy-database/live/products/partner_payout_job/15bd642b-06a4-4cff-94b5-b75c52cb2134.orc',
#  'otipy-database/live/products/partner_referral_share/0009ef0d-3823-49ce-be51-8f21d8003214.orc',
#  'otipy-database/live/products/partner_return_order/dt=2022-08-21/2022-08-21.orc',
#  'otipy-database/live/products/paytm_transaction/dt=2019-09-04/20220713_182832_09630_n8n8g_8333e3de-bb7e-435a-b47f-0f4287f4503c',
#  'otipy-database/live/products/prod_margin_profile/00fe343f-2085-4cfd-8cd1-0f08acc19bfb.orc',
#  'otipy-database/live/products/prod_stock_status/00044ed8-3b5c-4c71-b200-561b026c87de.orc',
#  'otipy-database/live/products/product_shuffling/000f0ced-99a5-46c4-a51f-de45f483beaf.orc',
#  'otipy-database/live/products/qc_bunch_mapping/001adaac-ff77-41fd-8e8e-c84ccaf350bf.orc',
#  'otipy-database/live/products/razorpay_transaction/0048a376-90d4-47b0-97a7-f7c4d3c520e2.orc',
#  'otipy-database/live/products/retailer_delivery_boy/00796931-9a53-46a3-8984-b24a3320c036.orc',
#  'otipy-database/live/products/retailer_delivery_boy_media/0027dd93-0843-4665-9d8b-02c574fba997.orc',
#  'otipy-database/live/products/sec_sell_transaction/0000f0ee-0592-4861-a4c0-6002d4effa35.orc',
#  'otipy-database/live/products/zone_product_deal/dt=2021-12-30/20220713_182924_09693_n8n8g_01f19be9-4504-412a-b2cd-93462a14a04f']

# %%
create_table[0]
# Out:
# "CREATE TABLE IF NOT EXISTS hive.products.b2c_margin(id Integer, prod_id Integer, prod_name varchar, quantity Decimal(10,2), price Decimal(10,2), po_id Integer, avg_price Decimal(10,2), avg_sale_price Decimal(10,2), n_slot_id Integer, distributor_id Integer) WITH(external_location = 's3a://presto-prod-otipy/otipy-database/live/products/b2c_margin', format='ORC')"

# %%
import trino
from trino.dbapi import connect
conn = connect(host="presto.crofarm.com",port=443,catalog='hive',http_scheme='https',auth=trino.auth.BasicAuthentication("db.manager","crofarm"))
cur = conn.cursor()

for i in create_table:
    try:
        #print(i)
        query = i
        cur.execute(query)
        rows = cur.fetchall()
        print(rows)
    except:
        print("exception", i)
        pass
# Out:
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
# [[True]]
